# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelNicola2H/Mate-Razonamiento-VERISON2-Samuel-Nicola-0106/blob/main/mate_p3_al_p5_samuel_nicola_0106.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Samuel Nicola NL = 40 Fecha 15/abril/2026
#
# ###Problema 3:
#  La resta de un númeroEnunciado: Un número al que se le resta siete da como resultado 18.Paso 1: Planteamiento y resoluciónDefinir la variable: Sea $x$ el número desconocido.Plantear la ecuación: "Un número ($x$) menos ($-$) 7 es igual ($=$) a 18".$$x - 7 = 18$$Despejar la variable: El 7 que está restando pasa al otro lado sumando para dejar sola a la $x$.$$x = 18 + 7$$Resultado:$$x = 25$$

# %%
# Definimos los datos del problema (vía input)
resultado = int(input("Ingrese el resultado: "))
resta = int(input("Ingrese la cantidad a restar: "))

# Despejamos x (x = resultado + resta)
numero_buscado = resultado + resta

print(f"El número es: {numero_buscado}")
# Out:
# Ingrese el resultado: 18
# Ingrese la cantidad a restar: 7
# El número es: 25

# %% [markdown]
# #### Problema 4:
#  El triple de un númeroEnunciado: El triple de un número más cuatro es igual a 31.Paso 1: Resolución matemáticaVariable: Sea $x$ el número.Ecuación: "El triple de un número ($3x$) más ($+$) cuatro ($4$) es igual ($=$) a $31$".$$3x + 4 = 31$$Despeje (paso 1): El 4 pasa restando:$$3x = 31 - 4$$$$3x = 27$$Despeje (paso 2): El 3 que multiplica a la $x$ pasa dividiendo:$$x = \frac{27}{3}$$Resultado: $x = 9$

# %%
# Definimos los valores conocidos (vía input)
total = int(input("Ingrese el total: "))
termino_independiente = int(input("Ingrese el término independiente: "))
coeficiente = int(input("Ingrese el coeficiente: "))

# Primero restamos el valor independiente y luego dividimos por el coeficiente
x = (total - termino_independiente) / coeficiente

print(f"El valor del número es: {int(x)}")
# Out:
# Ingrese el total: 31
# Ingrese el término independiente: 4
# Ingrese el coeficiente: 3
# El valor del número es: 9

# %% [markdown]
# #### Problema 5
# Dimensiones de un terreno rectangularEnunciado: El largo mide 5m más que el ancho. Perímetro total = 50m.Paso 1: Resolución matemáticaVariables:Ancho: $x$Largo: $x + 5$Ecuación del perímetro: El perímetro es la suma de los 4 lados ($2 \cdot \text{largo} + 2 \cdot \text{ancho}$):$$2(x + 5) + 2(x) = 50$$Simplificación:$$2x + 10 + 2x = 50$$$$4x + 10 = 50$$Despeje:$$4x = 50 - 10$$$$4x = 40$$$$x = \frac{40}{4} = 10$$Resultados:Ancho: 10 metros.Largo: $10 + 5 =$ 15 metros.

# %%
# Datos conocidos (vía input)
perimetro = int(input("Ingrese el perímetro total: "))
diferencia_largo = int(input("Ingrese cuánto más mide el largo respecto al ancho: "))

# Simplificamos la ecuación 4x + (2 * diferencia) = perimetro
# Despejamos x (el ancho): x = (perimetro - (2 * diferencia)) / 4
ancho = (perimetro - (2 * diferencia_largo)) / 4
largo = ancho + diferencia_largo

print(f"El ancho mide: {ancho}m")
print(f"El largo mide: {largo}m")
# Out:
# Ingrese el perímetro total: 50
# Ingrese cuánto más mide el largo respecto al ancho: 5
# El ancho mide: 10.0m
# El largo mide: 15.0m
